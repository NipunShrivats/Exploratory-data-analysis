# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # FIFA Dataset Analysis

# %%
fifa = pd.read_csv('D:/MY WORK/1. FULL STACK DS(ineuron)/Notebooks/9. EDA/Dataset/FIFA_data.csv')
fifa = fifa.drop('Unnamed: 0', axis = 1)
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
# name of all the columns
for f in fifa.columns:
    print(f)
# Out:
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
fifa.shape
# Out:
# (18207, 88)

# %%
fifa.Nationality.value_counts()[:10]
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
x = list(fifa.Nationality.value_counts()[:5].keys())
y = list(fifa.Nationality.value_counts()[:5])
print(x)
print(y)
# Out:
# ['England', 'Germany', 'Spain', 'Argentina', 'France']
# [1662, 1198, 1072, 937, 914]

# %%
# maximum number of players Nationality
plt.figure(figsize = (6, 6))
plt.bar(x, y, color = 'g')
plt.show()

# %%
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
# Player salary higest 5 and lowest 5
ps_top = fifa[['Name', 'Wage']][:5]
print(ps_top)
# Out:
#                 Name   Wage
# 0           L. Messi  €565K
# 1  Cristiano Ronaldo  €405K
# 2          Neymar Jr  €290K
# 3             De Gea  €260K
# 4       K. De Bruyne  €355K

# %%
# Graphs for highest and lowest paid players
# top- 5
x_top = list(ps_top['Name'])
y_top = list(ps_top['Wage'])

# %%
# top
plt.figure(figsize = (8, 8))
plt.rcParams.update({'font.size': 10})
plt.bar(x, y, color = 'g')
plt.show()

# %% [markdown]
# # German Players

# %%
ger = fifa[fifa.Nationality == 'Germany']
ger.head()
# Out:
#         ID           Name  Age  \
# 11  182521       T. Kroos   28
# 18  192448  M. ter Stegen   26
# 22  167495       M. Neuer   32
# 34  178603     M. Hummels   29
# 55  222492        L. Sané   22
#
#                                              Photo Nationality  \
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 22  https://cdn.sofifa.org/players/4/19/167495.png     Germany
# 34  https://cdn.sofifa.org/players/4/19/178603.png     Germany
# 55  https://cdn.sofifa.org/players/4/19/222492.png     Germany
#
#                                    Flag  Overall  Potential  \
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 18  https://cdn.sofifa.org/flags/21.png       89         92
# 22  https://cdn.sofifa.org/flags/21.png       89         89
# 34  https://cdn.sofifa.org/flags/21.png       88         88
# 55  https://cdn.sofifa.org/flags/21.png       86         92
#
# ...

# %%
# max wage - This is not sensing the wages properly according to the ascending and dscending order
wages = ger.sort_values(by = ['Wage'], ascending = True)
wages[['Name', 'Wage', 'Age', 'Height', 'Weight']].head()
# Out:
#             Name   Wage  Age Height  Weight
# 68       M. Reus  €100K   29   5'11  157lbs
# 3275  M. Lehmann   €10K   35   5'10  165lbs
# 4542  T. Kessler   €10K   32    6'6  203lbs
# 5536  T. Eisfeld   €10K   25   5'10  168lbs
# 6042  L. Klünter   €10K   22    6'0  161lbs

# %%
# max height
height = ger.sort_values(by = ['Height'], ascending = False)
height[['Name', 'Wage', 'Age', 'Height', 'Weight']].head()
# Out:
#                 Name  Wage  Age Height  Weight
# 1426   L. Unnerstall  €12K   27    6'6  227lbs
# 13540    F. Stritzel   €2K   24    6'6  203lbs
# 17786   A. Weidinger   €1K   21    6'6  194lbs
# 13520   L. Watkowiak   €1K   22    6'6  236lbs
# 4542      T. Kessler  €10K   32    6'6  203lbs

# %%
# max Weight
weight = ger.sort_values(by = ['Weight'], ascending = False)
weight[['Name', 'Wage', 'Age', 'Height', 'Weight']].head()
# Out:
#                 Name  Wage  Age Height  Weight
# 13520   L. Watkowiak   €1K   22    6'6  236lbs
# 1426   L. Unnerstall  €12K   27    6'6  227lbs
# 210      R. Fährmann  €38K   29    6'6  216lbs
# 1225        M. Esser  €24K   30    6'6  214lbs
# 115          N. Süle  €84K   22    6'5  214lbs

# %% [markdown]
# # Shooting Skills

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
skill = fifa.sort_values(by = ['Skill Moves'], ascending = False)
skill = skill[['Name', 'Age', 'Skill Moves']]
skill.head()
# Out:
#             Name  Age  Skill Moves
# 2878    A. Maxim   27          5.0
# 221    F. Ribéry   35          5.0
# 153     Quaresma   34          5.0
# 45      P. Pogba   25          5.0
# 370   X. Shaqiri   26          5.0

# %%
shot = fifa.sort_values(by = ['ShotPower'], ascending = False)
shot = shot[['Name', 'Age', 'ShotPower']]
shot.head()
# Out:
#                    Name  Age  ShotPower
# 1     Cristiano Ronaldo   33       95.0
# 378                Hulk   31       94.0
# 1348          F. Guarín   32       93.0
# 890         L. Podolski   33       92.0
# 36              G. Bale   28       92.0

# %% [markdown]
# # Penalty

# %%
Penalty = fifa.sort_values(by = ['Penalties'], ascending = False)
Penalty = shot[['Name', 'Age', 'Penalties']]
Penalty.head()
# Out:
#              Name  Age  Penalties
# 206  M. Balotelli   27       92.0
# 118       Fabinho   24       91.0
# 16        H. Kane   24       90.0
# 297      M. Kruse   30       90.0
# 945     L. Baines   33       90.0

# %%
fifa
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %% [markdown]
# # CLUBS

# %%
real = fifa[fifa.Club == 'Real Madrid']
real.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# higest paid in real_marid
high = real.sort_values(by = 'Wage', ascending = True)
high[['Name', 'Age', 'Nationality', 'Wage']]
# Out:
#                   Name  Age         Nationality   Wage
# 697       Kiko Casilla   31               Spain  €105K
# 573    Marcos Llorente   23               Spain  €110K
# 417          Odriozola   22               Spain  €115K
# 328      Dani Ceballos   21               Spain  €120K
# 12504       Dani Gómez   19               Spain   €12K
# 430            Mariano   24  Dominican Republic  €140K
# 188    Nacho Fernández   28               Spain  €180K
# 123           Carvajal   26               Spain  €185K
# 46            K. Navas   31          Costa Rica  €195K
# 172      Lucas Vázquez   27               Spain  €205K
# 10269          Fidalgo   21               Spain   €20K
# 62           R. Varane   25              France  €210K
# 79       Marco Asensio   22               Spain  €215K
# 10178  F. Feuillassier   20           Argentina   €23K
# 105         K. Benzema   30              France  €240K
# 19         T. Courtois   26             Belgium  €240K
# ...

# %%
high['Wage'].dtypes
# Out:
# dtype('O')

# %%
wage = high['Wage'].astype('string')
high['Wage'].dtypes
# Out:
# dtype('O')

# %%
# stamina
high = real.sort_values(by = 'Stamina', ascending = False)
high[['Name', 'Age', 'Nationality', 'Stamina', 'Wage']].head()
# Out:
#               Name  Age Nationality  Stamina   Wage
# 35         Marcelo   30      Brazil     91.0  €285K
# 172  Lucas Vázquez   27       Spain     90.0  €205K
# 6        L. Modrić   32     Croatia     89.0  €420K
# 27        Casemiro   26      Brazil     87.0  €285K
# 123       Carvajal   26       Spain     84.0  €185K

# %%
high['Wage'].convert_dtypes().dtypes
# Out:
# StringDtype
